# %% [markdown]
# <a href="https://colab.research.google.com/github/dansek-dj/DeepLearning/blob/main/01_Neural_Networks_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic Regression problem with `tensorflow`

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
display(np.__version__)
# Out:
# 2.11.0
# '1.22.4'

# %%
X = np.array([-4, -3, 0, 5, 9, 25, 32])
y = np.array([6, 7, 10, 15, 19, 35, 42])
plt.scatter(X, y)

# %% [markdown]
# > Convert the numpy array into tensors

# %%
X = tf.constant(X)
y = tf.constant(y)
X, y
# Out:
# (<tf.Tensor: shape=(7,), dtype=int64, numpy=array([-4, -3,  0,  5,  9, 25, 32])>,
#  <tf.Tensor: shape=(7,), dtype=int64, numpy=array([ 6,  7, 10, 15, 19, 35, 42])>)

# %% [markdown]
# ##Steps in creating a model
#
# 1. **Create a model** - define the input and output layers as well as the hidden layers of a deep learning model.
# 2. **Compiling a model** - define the loss function (in other words, the function which tells our model how wrong it is) and the optimizer (tells our model how to improve the patterns its learning) and evaluation metrics (what we can use to interpret the performance of our model).
# 3. **Ftting a model** - letting the model try to find patterns between X & y (features and labels).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create a model using Sequential API
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
    ])

# 2. Compile the model
model.compile(loss = tf.keras.losses.mae, # mae is the mean absolute error
              optimizer = tf.keras.optimizers.Adam(),
              metrics = ['mae'])

##. Fit the model
model.fit(tf.expand_dims(X, axis = -1), y, epochs = 5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 873ms/step - loss: 26.2214 - mae: 26.2214
# Epoch 2/5
# 1/1 [==============================] - 0s 11ms/step - loss: 26.2113 - mae: 26.2113
# Epoch 3/5
# 1/1 [==============================] - 0s 10ms/step - loss: 26.2011 - mae: 26.2011
# Epoch 4/5
# 1/1 [==============================] - 0s 8ms/step - loss: 26.1910 - mae: 26.1910
# Epoch 5/5
# 1/1 [==============================] - 0s 8ms/step - loss: 26.1809 - mae: 26.1809

# %%
model.predict([54.0])
# Out:
# 1/1 [==============================] - 0s 155ms/step
# array([[-41.532803]], dtype=float32)

# %% [markdown]
# ##Improve our model
# 1. **Creating a model** - here we might add more layers, increase the number of hidden units/neurons within each of the hidden layers, change the activation function of each layer.
# 2. **Compiling a model** - here we might change the optimizer, **learning rate**
# 3. **Fitting a model** - here might increase the epochs, add more data

# %%
# let's rebuild our model

#1.Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

#2. Compile the model 
model.compile(loss = tf.keras.losses.mae, 
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ['mae'])

#3. Fit the model
model.fit(tf.expand_dims(X, axis =-1), y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 469ms/step - loss: 12.3258 - mae: 12.3258
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 11.4799 - mae: 11.4799
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 10.6340 - mae: 10.6340
# Epoch 4/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.7880 - mae: 9.7880
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.9421 - mae: 8.9421
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0962 - mae: 8.0962
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.2503 - mae: 7.2503
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0929 - mae: 7.0929
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0878 - mae: 7.0878
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0827 - mae: 7.0827
# Epoch 11/100
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 82ms/step
# array([[23.0726]], dtype=float32)

# %%
#1.Create the model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1, input_shape = (1,)))
model.add(tf.keras.layers.Dense(100))

#2. Compile the model 
model.compile(loss = tf.keras.losses.mae, 
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ['mae'])

#3. Fit the model
model.fit(tf.expand_dims(X, axis =-1), y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 594ms/step - loss: 19.1341 - mae: 19.1341
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 19.1302 - mae: 19.1302
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 19.1264 - mae: 19.1264
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 19.1226 - mae: 19.1226
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 19.1187 - mae: 19.1187
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 19.1149 - mae: 19.1149
# Epoch 7/100
# 1/1 [==============================] - 0s 14ms/step - loss: 19.1110 - mae: 19.1110
# Epoch 8/100
# 1/1 [==============================] - 0s 12ms/step - loss: 19.1072 - mae: 19.1072
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 19.1033 - mae: 19.1033
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 19.0994 - mae: 19.0994
# ...

# %%
# let's rebuild our model

#1.Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(1),
    #tf.keras.layers.Dense(100)
])

#2. Compile the model 
model.compile(loss = tf.keras.losses.mae, 
              optimizer = tf.keras.optimizers.Adam(lr = 0.01),
              metrics = ['mae'])

#3. Fit the model
model.fit(tf.expand_dims(X, axis =-1), y, epochs = 100, verbose = 1)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 20.5938 - mae: 20.5938
# Epoch 2/100
# 1/1 [==============================] - 0s 37ms/step - loss: 20.4419 - mae: 20.4419
# Epoch 3/100
# 1/1 [==============================] - 0s 41ms/step - loss: 20.2901 - mae: 20.2901
# Epoch 4/100
# 1/1 [==============================] - 0s 30ms/step - loss: 20.1382 - mae: 20.1382
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 19.9862 - mae: 19.9862
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 19.8341 - mae: 19.8341
# Epoch 7/100
# 1/1 [==============================] - 0s 11ms/step - loss: 19.6820 - mae: 19.6820
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 19.5298 - mae: 19.5298
# Epoch 9/100
# ...
